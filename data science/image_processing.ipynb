# %%
from PIL import Image , ImageFilter , ImageDraw,ImageFont,ImageEnhance

# %%
imp1 = Image.open(r"c:\Users\Lenovo\Pictures\Screenshots\Screenshot 2024-08-05 222805.png")

# %%
imp1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=596x447>

# %%
print(imp1.size)
print(imp1.mode)
print(imp1.format)
print(imp1.width , imp1.height)
# Out:
# (596, 447)
# RGBA
# PNG
# 596 447

# %%
imp1.resize((300,300))
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300>

# %%
w= imp1.width
h=imp1.height
imp1.resize((int(w*.5),int(h*.5)))
# Out:
# <PIL.Image.Image image mode=RGBA size=298x223>

# %%
imp1.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGBA size=596x447>

# %%
imp1.filter(ImageFilter.EMBOSS)
# Out:
# <PIL.Image.Image image mode=RGBA size=596x447>

# %%
imp1.filter(ImageFilter.CONTOUR)
# Out:
# <PIL.Image.Image image mode=RGBA size=596x447>

# %%
imp1.filter(ImageFilter.EDGE_ENHANCE)
# Out:
# <PIL.Image.Image image mode=RGBA size=596x447>

# %%
imp1.filter(ImageFilter.FIND_EDGES).save("goku_edges.png")

# %%
imp1.filter(ImageFilter.GaussianBlur(1))
# Out:
# <PIL.Image.Image image mode=RGBA size=596x447>

# %%
en1=ImageEnhance.Color(imp1)
for i in range (-5,6,1):
    en1.enhance(i).show()

# %%
en1.degenerate
# Out:
# <PIL.Image.Image image mode=RGBA size=596x447>

# %%
en2 = ImageEnhance.Contrast(imp1)
en2.enhance(2)
# Out:
# <PIL.Image.Image image mode=RGBA size=596x447>

# %%
en2.enhance(-2)
# Out:
# <PIL.Image.Image image mode=RGBA size=596x447>

# %% [markdown]
# drawing  on images

# %%
imp1
f1=ImageFont.truetype(r"c:\Windows\Fonts\ALGER.TTF")
d = ImageDraw(imp1)
d.text((100,100) ,"ER DDIAGRAM",FILL = "red",font = f1)
imp1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 imp1
#       2 f1=ImageFont.truetype(r"c:\Windows\Fonts\ALGER.TTF")
# ----> 3 d = ImageDraw(imp1)
#       4 d.text((100,100) ,"ER DDIAGRAM",FILL = "red",font = f1)
#       5 imp1
#
# TypeError: 'module' object is not callable
