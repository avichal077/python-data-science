# %%
from dputils.scrape import Scraper , Tag

# %%
url = "https://digipodium.com/mining-demo.html"
scl = Scraper(url)

# %%
scl.soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>Data Mining Demo</title>
# <!-- Required meta tags -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <!-- Bootstrap CSS v5.2.1 -->
# <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.1/dist/css/bootstrap.min.css" integrity="sha384-iYQeCzEYFbKjA/T2uDLTpkwGzCiq6soy8tYaI1GyVh/UjpbCx/TYkiZhlZB6+fzT" rel="stylesheet"/>
# <!-- Bootstrap Icons CSS v1.6.1 -->
# <link href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.6.1/font/bootstrap-icons.css" rel="stylesheet"/>
# <style>
#         :root {
#             --bs-indigo: #6610f2;
#         }
#     </style>
# </head>
# <body>
# <header>
# <nav class="navbar navbar-expand-lg navbar-dark bg-danger">
# <div class="container">
# <a class="navbar-brand mx-auto" href="#">Digipodium Workshop 2024</a>
# ...

# %%
scl.get_repeating_date_from_page?
# Out:
# Signature:
# scl.get_repeating_date_from_page(
#     target: dputils.scrape.Tag = None,
#     items: dputils.scrape.Tag = None,
#     errors=False,
#     info=False,
#     **tags,
# ) -> list
# Docstring:
# Extracts data for multiple items based on given Tag objects and returns a list of dictionaries.
#
# Args:
#     target (Tag): Tag object to identify the main section (Default is None).
#     items (Tag): Tag object to identify items within the main section (Default is None).
#     errors (bool): Flag to print errors (Default is False).
#     info (bool): Flag to print information messages (Default is False).
#
# Returns:
#     list: List of dictionaries containing extracted data for each item.
# File:      c:\users\lenovo\miniconda3\lib\site-packages\dputils\scrape.py
# Type:      method

# %%
target = Tag("main")
items = Tag(cls = 'col')
title = Tag('h4')
price = Tag('h1')

# %%
scl.get_repeating_date_from_page(
    target = target,
    items= items,
    title = title,
    price = price , 
)
# Out:
# [{'title': 'LuxoWatch ', 'price': '₹5949.82'},
#  {'title': 'SuperPhone X', 'price': '₹67118.07'},
#  {'title': 'Miracle Blender', 'price': '₹3689.88'},
#  {'title': 'Quantum Headphones', 'price': '₹9709.69'},
#  {'title': 'SmartFridge', 'price': '₹89699.05'},
#  {'title': 'Galactic Glasses', 'price': '₹2234.52'},
#  {'title': 'PowerJuicer', 'price': '₹6651.27'},
#  {'title': 'iSpectre Laptop', 'price': '₹119647.11'},
#  {'title': 'HealthBand', 'price': '₹5228.64'},
#  {'title': 'MaxiSound Speaker', 'price': '₹14908.25'},
#  {'title': 'UltraSound Toothbrush', 'price': '₹2456.50'},
#  {'title': 'SuperFit Smartwatch', 'price': '₹3679.99'},
#  {'title': 'GoPro Hero 9', 'price': '₹28999.00'},
#  {'title': 'AirPods Pro', 'price': '₹12780.50'},
#  {'title': 'Fitness Treadmill', 'price': '₹38999.00'},
#  {'title': 'Bluetooth Headphones', 'price': '₹1649.99'},
#  {'title': 'Smart Thermostat', 'price': '₹2999.00'},
#  {'title': 'Automatic Coffee Maker', 'price': '₹6299.99'},
# ...

# %%
def get_items_from_flipkart(query , page = 1):
    url = 'https://www.flipkart.com/search?q={query}&page = {page}'
    sc2 = Scraper(url)
    t = Tag(cls = 'DOjaWF gdgoEp')
    i = Tag(cls = 'slAVV4')
    sc2.get_repeating_date_from_page(
        target = t,
        items = i,
        image = Tag('img',cls = 'DByuf4',output = 'src'),
        link = Tag('a',cls = 'VJA3rP',output = 'href'),
        title = Tag('a',cls = 'wjcEIp')
    )

# %%
query = "books"
page = 1
all_data = []
while True:
    data = get_items_from_flipkart(query ,page)
    if len(data) > 0
        print(f"Scraper{page=}")
        all_data.extend(data)
        page = page +1
    else : 
        print("Stopping , no more data")
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 6
#       4 while True:
#       5     data = get_items_from_flipkart(query ,page)
# ----> 6     if len(data) > 0:
#       7         print(f"Scraper{page=}")
#       8         all_data.extend(data)
#
# TypeError: object of type 'NoneType' has no len()

# %%
import pandas as pd
pd.DataFrame(all_data).to_csv('books.csv',index = False)
