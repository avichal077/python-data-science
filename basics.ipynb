# %% [markdown]
# # Basics
# - variable
# - input
# - ouput

# %%
x = 1.90
y = "lucknow"

# %%
a = [1, 2, 3, 4]
b = {'name': 'raju', 'age': 12}

# %%
x
# Out:
# 1.9

# %%
name = input("enter your name")

# %%
city = input("enter your city")
fav_movie = input("enter your fav movie")
fav_color = input("enter your fav color")

# %%
num1 = input("enter a number A")
num2 = input("enter a number B")

# %% [markdown]
# ## displaying data

# %%
print('Welcome to Displaying Data') # static message to display
# Out:
# Welcome to Displaying Data

# %%
a = 'Alex'
b = 'Baron'
print(a) # display the value of a
print(b) # display the value of b
# Out:
# Alex
# Baron

# %%
print(a, b)
print(a, a, a, a)
# Out:
# Alex Baron
# Alex Alex Alex Alex

# %%
name = input('enter your name')
print('Your name is', name)
# Out:
# Your name is Hariom

# %%
num1 = input('enter a number')
num2 = input('enter another number')
print('The first num is', num1, 'and the second num is', num2)
# Out:
# The first num is 12 and the second num is 45

# %%
print('The first num is', num1)
print()
print('and the second num is', num2)
# Out:
# The first num is 12
#
# and the second num is 45

# %% [markdown]
# `displaying data with messages`
#
# 1. comma seperated ✅
# 2. format string
# 3. format method
# 4. string concatenation
# 5. f-string

# %%
# format string
a, b, c = 5, 3.2, "Hello" # multiple assignment
print("the values are %d, %f, %s" % (a, b, c)) # %d = int, %f = float, %s = string
print("the values are %s, %d, %f" % (c, a, b)) 
print("the values are %s, %s, %s" % (c, a, b))
# Out:
# the values are 5, 3.200000, Hello
# the values are Hello, 5, 3.200000
# the values are Hello, 5, 3.2

# %%
# format method
print('the value of a=>{}, b=>{}, c=>{}'.format(a,b,c))
# Out:
# the value of a=>5, b=>3.2, c=>Hello

# %%
# string concatenation
print('Hello' + 'World')
print('the value of a=' + str(a))
print('the value of c=' + c)
print('the value of b=' + str(b))
# Out:
# HelloWorld
# the value of a=5
# the value of c=Hello
# the value of b=3.2

# %%
# f-string
print(f'the value of a=>{a}, b=>{b}, c=>{c}')
# Out:
# the value of a=>5, b=>3.2, c=>Hello

# %% [markdown]
# ### f-string setting

# %%
# formatting values
a,b = 10,3
print(f'{a}/{b} = {a/b}')
print(f'{a}/{b} = {a/b:.2f}') # .2f = 2 decimal places
# Out:
# 10/3 = 3.3333333333333335
# 10/3 = 3.33

# %%
# alignment
name = 'Alex'
print(f'Your are {name}')
print(f'Your are {name:10}') # 10 here is number of characters for display 
print(f'Your are {name:>10}') # right alignment
print(f'Your are {name:^10}') # center alignment
# Out:
# Your are Alex
# Your are Alex
# Your are       Alex
# Your are    Alex

# %%
a,b,c,d ='Apple', 'Blueberry', 'Cherry', 'Dragonfruit'
print(f'🍎 fruit 1: {a:>12}')
print(f'🍇 fruit 2: {b:>12}')
print(f'🍒 fruit 3: {c:>12}')
print(f'🍉 fruit 4: {d:>12}')
# Out:
# 🍎 fruit 1:       Apple
# 🍇 fruit 2:   Blueberry
# 🍒 fruit 3:      Cherry
# 🍉 fruit 4: Dragonfruit

# %% [markdown]
# # operators
# - arithmetic
# - assignment
# - comparision
# - logical
# - relationship
# - identity
# - bitwise

# %%
x = 10
y = 3
print(f'{x}+{y}={x+y}')
print(f'{x}-{y}={x-y}')
print(f'{x}*{y}={x*y}')
print(f'{x}/{y}={x/y}')
print(f'{x}//{y}={x//y}')
print(f'{x}**{y}={x**y}')
# Out:
# 10+3=13
# 10-3=7
# 10*3=30
# 10/3=3.3333333333333335
# 10//3=3
# 10**3=1000

# %%
print(x>y)
print(x<y)
print(x==y)
print(x<=y)
print(x>=y)
# Out:
# True
# False
# False
# False
# True

# %%
x > y and x < 100
# Out:
# True

# %%
x > y and x > 100 # this will not be displaced 
x > 15 or y > 10
# Out:
# False

# %%
fruits = ['apple','banana','cherry','date','elderberry']
print('cherry' in fruits )
print('CHERRY' in fruits )
print('blueberry' in fruits )
print('apple' in fruits )
# Out:
# True
# False
# False
# True

# %%
# this is not the best concept
f = fruits # f is a refrence to fruits 
print(f is fruits )
f2 = fruits.copy() # f2 is a copy off fruits 
print(f2 is fruits )
# Out:
# True
# False

# %% [markdown]
# # typecasting

# %%
x = 10
xf = float(x)
xs = str(x)
print(x,xf)
print(type(x),type(xf))
# checking is x is a integer
print(isinstance(x , int))
print(isinstance(xf , int))
print(isinstance(x , str))
print(isinstance(xs,(int , float )))
print(isinstance(x,(int , float )))
# Out:
# 10 10.0
# <class 'int'> <class 'float'>
# True
# False
# False
# False
# True

# %%
int('20a') # thsi will not work
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 int('20a')
#
# ValueError: invalid literal for int() with base 10: '20a'

# %%
ord('a') # returns the unicode of a character
# Out:
# 97

# %%
print(chr(15108))# returns the character of a unicode
# Out:
# 㬄

# %%
a = int(input('enter first number '))
b = int(input('enter second number '))
print(a + b)
# Out:
# 400
